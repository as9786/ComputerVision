# %% [markdown]
# <a href="https://colab.research.google.com/github/as9786/ComputerVision/blob/main/NumpyImage/Image%26Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numpy에서는 JPEG나 PNG file 확장자를 바로 열 수 없음
#
# PIL library 사용

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image #이미지를 열게 해주고 numpy가 이해할 수 있는 배열로 바꿔줌

# %%
pic = Image.open('/content/drive/MyDrive/train_pet/dogs/dog.1.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=327x499 at 0x7FEFF0FDDE50>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (499, 327, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red  = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (499, 327, 3)

# %%
# R G B
# Red channel values 0-255
plt.imshow(pic_red[:,:,0])

# %%
pic_red[:,:,0]
# Out:
# array([[235, 167, 136, ..., 131, 126, 125],
#        [248, 172, 131, ..., 115, 111, 110],
#        [247, 169, 129, ...,  85,  83,  84],
#        ...,
#        [255, 254, 250, ..., 239, 238, 238],
#        [255, 255, 252, ..., 245, 244, 244],
#        [255, 255, 254, ..., 250, 248, 249]], dtype=uint8)

# %%
plt.imshow(pic_red[:,:,0],cmap='gray')

# %%
plt.imshow(pic_red[:,:,1],cmap='gray')

# %%
plt.imshow(pic_red[:,:,2],cmap='gray')

# %% [markdown]
# gray를 적용해도 미묘하게 다름
#
# 적색 수치가 255라는 얘기는 완전히 빨간색이라는 것
#
# 0은 빨간색이 없고 검정이라는 뜻
#
# gray로 바꿨을 시 해당 색조가 높은 부분은 밝게 아니면 어둡게 나옴

# %%
# Green channel
pic_red[:,:,:1] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (499, 327, 3)

# %%
pic_red[:,:,1].shape
# Out:
# (499, 327)
