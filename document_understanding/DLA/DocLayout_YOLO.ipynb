# %% [markdown]
# # 0. 설치

# %%
pip install doclayout-yolo

# %% [markdown]
# # 1. 추론

# %%
import cv2
from doclayout_yolo import YOLOv10
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/content/drive/MyDrive/CV/academic.jpg')
plt.imshow(img)

# %%
model = YOLOv10("/content/drive/MyDrive/CV/doclayout_yolo_docstructbench_imgsz1024.pt")

# %%
plt.imshow(model(img)[0].plot())
# Out:
# 0: 1024x736 1 title, 4 plain texts, 4 abandons, 2 figures, 3 figure_captions, 2 tables, 103.2ms
# Speed: 8.2ms preprocess, 103.2ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 736)
